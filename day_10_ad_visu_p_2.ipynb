# %% [markdown]
# <a href="https://colab.research.google.com/github/mannapoorani052-glitch/project-1/blob/main/day_10_ad_visu_p_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

marks=[45,56,78,88,67,90,76,55,82,95]
plt.boxplot(marks)

plt.title("Students marks")
plt.show()

# %% [markdown]
# **HEAT MAP**

# %%
import numpy as np
data=np.array([
               [80,75,90,],
               [55,78,98],
               [70,64,57]]
  )

plt.imshow(data,cmap='pink')
plt.colorbar()
plt.show()

# %% [markdown]
# ***bubble chart***

# %%
study_hours=[1,2,3,4,5]
marks=[44,55,65,75,90]
attendance=[100,99,98,99,1000]

plt.scatter(study_hours,marks,s=attendance)
plt.xlabel("study_hours")
plt.ylabel("marks")
plt.show()
